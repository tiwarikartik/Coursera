# %% [markdown]
# ![1-title.png](attachment:97a2c286-6e29-4503-b64b-a7a9dff87a4d.png)

# %% [markdown]
# # Data Science Tools and Ecosystem
# ![2-title.png](attachment:f62477c7-0c73-4cbf-91b7-5ae097138aba.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.
# ![image.png](attachment:a3bbfa8b-441e-4d4f-8300-4fbfb88d4150.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. R
# 2. Python
# 3. SQL
# ![dslanguages.png](attachment:1713945a-9bc5-43aa-915a-1036c0d6efe6.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1. PyTorch
# 2. TensorFlow
# 3. OpenCV
# 4. Pandas
# 5. Scikit-learn
# 6. Caffe
# 7. Matplotlib
# ![5-dslibraries.png](attachment:5649244f-50f7-45ce-b2fa-c253de0a5bc3.png)

# %% [markdown]
# |Data Science Tools|
# --------------------
# |Driverless.H20|
# |Rapidminer|
# |Apache Kafka|
# |cassandra|
# |Hadoop|
# ![6-dstools.png](attachment:8626c40f-3d4a-402e-8a06-fe21a99011b9.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python
# - 1 + 2 = 3
# - 2 * 2 = 4
# - 3 ** 3 = 27
# ![7-introarithmetic.png](attachment:5a5cbaf1-6c33-467e-91a8-bac5eba9d488.png)

# %%
# This a simple arithmetic expression to mutiply then add integers
print((3*4)+5)
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers.png](attachment:0ac81180-87fa-42f4-b6f4-a22f7fab51e7.png)

# %%
# This will convert 200 minutes to hours by diving by 60
def minutesToHours(minutes):
    if minutes % 60 == 0:
        print(f"{minutes // 60} hours")
    else:
        print(f"{minutes // 60} hours and {minutes % 60} minutes")

minutesToHours(200)
# Out:
# 3 hours and 20 minutes

# %% [markdown]
# ![9-hourstominutes.png](attachment:619c3bf2-e2e2-4fbe-a6fb-ee3d689d6312.png)

# %% [markdown]
# **Objectives:**
#
# Create a Jupyter Notebook
# Insert code and markdown cells
# Learn Languages for data Science:
# - Python
# - R
# - SQL
#
# ![10-objectives.png](attachment:7be94272-d397-489f-9eba-8f75452f4bcf.png)tHub

# %% [markdown]
# ## Author:
# Kartik Tiwari
# ![11-authordetails.png](attachment:4838209b-e847-444a-a7f8-aa2ba7c28ffd.png)
